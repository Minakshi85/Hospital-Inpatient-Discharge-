# %% [markdown]
# ### Bronze Data Analysis

# %%
file_path = 'abfss://d5d4a0bc-04c6-4ae3-ae88-3b02cfbf37a8@onelake.dfs.fabric.microsoft.com/e9762736-9ad0-42b8-a949-2997f0bb5338/Files/Landing'
# Out:
# StatementMeta(, 6bd4ba6b-01b9-42d8-8215-3e751a06089d, 3, Finished, Available, Finished, False)

# %%
df = spark.read.format('csv').option('header','true').load(file_path)
display(df)
# Out:
# StatementMeta(, 6bd4ba6b-01b9-42d8-8215-3e751a06089d, 5, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 7bc7e742-ed92-423d-a913-7b6dfec2b43e)

# %%
df.dtypes
# Out:
# StatementMeta(, 6bd4ba6b-01b9-42d8-8215-3e751a06089d, 6, Finished, Available, Finished, False)
# [('Health Service Area', 'string'),
#  ('Hospital County', 'string'),
#  ('Operating Certificate Number', 'string'),
#  ('Facility Id', 'string'),
#  ('Facility Name', 'string'),
#  ('Age Group', 'string'),
#  ('Zip Code - 3 digits', 'string'),
#  ('Gender', 'string'),
#  ('Race', 'string'),
#  ('Ethnicity', 'string'),
#  ('Length of Stay', 'string'),
#  ('Type of Admission', 'string'),
#  ('Patient Disposition', 'string'),
#  ('Discharge Year', 'string'),
#  ('CCS Diagnosis Code', 'string'),
#  ('CCS Diagnosis Description', 'string'),
#  ('CCS Procedure Code', 'string'),
#  ('CCS Procedure Description', 'string'),
#  ('APR DRG Code', 'string'),
#  ('APR DRG Description', 'string'),
#  ('APR MDC Code', 'string'),
#  ('APR MDC Description', 'string'),
#  ('APR Severity of Illness Code', 'string'),
#  ('APR Severity of Illness Description', 'string'),
# ...

# %%
df.printSchema()
# Out:
# StatementMeta(, 6bd4ba6b-01b9-42d8-8215-3e751a06089d, 12, Finished, Available, Finished, False)
# root
#  |-- Health_Service_Area: string (nullable = true)
#  |-- Hospital_County: string (nullable = true)
#  |-- Operating_Certificate_Number: string (nullable = true)
#  |-- Facility_Id: string (nullable = true)
#  |-- Facility_Name: string (nullable = true)
#  |-- Age_Group: string (nullable = true)
#  |-- Zip_Code_3_digits: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Race: string (nullable = true)
#  |-- Ethnicity: string (nullable = true)
#  |-- Length_of_Stay: string (nullable = true)
#  |-- Type_of_Admission: string (nullable = true)
#  |-- Patient_Disposition: string (nullable = true)
#  |-- Discharge_Year: string (nullable = true)
#  |-- CCS_Diagnosis_Code: string (nullable = true)
#  |-- CCS_Diagnosis_Description: string (nullable = true)
#  |-- CCS_Procedure_Code: string (nullable = true)
#  |-- CCS_Procedure_Description: string (nullable = true)
# ...

# %%
for col_name in df.columns:
    df = df.withColumnRenamed(col_name, col_name.replace(" ","_").replace("-","_"))
# Out:
# StatementMeta(, 6bd4ba6b-01b9-42d8-8215-3e751a06089d, 9, Finished, Available, Finished, False)

# %%
df = df.withColumnRenamed("Zip_Code___3_digits", "Zip_Code_3_digits")
# Out:
# StatementMeta(, 6bd4ba6b-01b9-42d8-8215-3e751a06089d, 11, Finished, Available, Finished, False)

# %%
df.write.mode('overwrite').format('delta').saveAsTable('LH_Discharge.Bronze.Bronzetable')
# Out:
# StatementMeta(, 6bd4ba6b-01b9-42d8-8215-3e751a06089d, 13, Finished, Available, Finished, False)
